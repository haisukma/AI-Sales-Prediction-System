# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/diajeng/Documents/AI-Sales-Prediction-System/data/sales_data.csv')

# %%
df.head()
# Out:
#   product_id product_name  jumlah_penjualan  harga  diskon status
# 0     P00001     Produk 1                57  26556      25  Tidak
# 1     P00002     Produk 2               140  84196       5  Laris
# 2     P00003     Produk 3                71  46868      25  Tidak
# 3     P00004     Produk 4               279  42790      20  Laris
# 4     P00005     Produk 5               216  28331       0  Laris

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   product_id        5000 non-null   object
#  1   product_name      5000 non-null   object
#  2   jumlah_penjualan  5000 non-null   int64
#  3   harga             5000 non-null   int64
#  4   diskon            5000 non-null   int64
#  5   status            5000 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 234.5+ KB

# %%
df.describe()
# Out:
#        jumlah_penjualan          harga       diskon
# count       5000.000000    5000.000000  5000.000000
# mean         150.052000  110792.249800    14.774000
# std           86.837583   51792.314449     9.948302
# min            0.000000   20044.000000     0.000000
# 25%           74.000000   66053.250000     5.000000
# 50%          152.000000  111320.000000    15.000000
# 75%          225.000000  155962.250000    25.000000
# max          300.000000  199991.000000    30.000000

# %%
df.isnull().sum()
# Out:
# product_id          0
# product_name        0
# jumlah_penjualan    0
# harga               0
# diskon              0
# status              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['status'].value_counts()
# Out:
# status
# Laris    3608
# Tidak    1392
# Name: count, dtype: int64

# %%
df[['jumlah_penjualan', 'harga', 'diskon']].boxplot()
# Out:
# <Axes: >

# %%
df['diskon'].unique()
# Out:
# array([25,  5, 20,  0, 10, 30, 15])

# %%
sns.heatmap(df[['jumlah_penjualan', 'harga', 'diskon']].corr(), annot=True)
plt.show()

# %%
sns.boxplot(x='status', y='jumlah_penjualan', data=df)
plt.show()

sns.boxplot(x='status', y='harga', data=df)
plt.show()

sns.boxplot(x='status', y='diskon', data=df)
plt.show()

# %%
df.groupby('status')[['jumlah_penjualan']].mean()
# Out:
#         jumlah_penjualan
# status
# Laris         192.001386
# Tidak          41.321121

# %%
import seaborn as sns

sns.boxplot(x='status', y='jumlah_penjualan', data=df)
# Out:
# <Axes: xlabel='status', ylabel='jumlah_penjualan'>

# %%
df.groupby('status')['jumlah_penjualan'].min()
# Out:
# status
# Laris    81
# Tidak     0
# Name: jumlah_penjualan, dtype: int64

# %%
df.groupby('status')['jumlah_penjualan'].max()
# Out:
# status
# Laris    300
# Tidak     80
# Name: jumlah_penjualan, dtype: int64
